# %%
import cv2

# %%
SAVE_DIR = './output'
counter = 0

# %%
cap = cv2.VideoCapture('cardi.mp4')
fps = cap.get(cv2.CAP_PROP_FPS)

print(f'The frames per second is: {fps}')

# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")
 
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    # Display the resulting frame
    cv2.imwrite('./output/' + str(counter).zfill(6) + '.jpg', frame)
    counter+=1
 
  # Break the loop
  else: 
    break
 
# When everything done, release the video capture object
cap.release()
 
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# The frames per second is: 23.976023976023978
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4ca448956116> in <module>
#      15     # Display the resulting frame
#      16     cv2.imshow('Frame',frame)
# ---> 17     cv2.imwrite('./output/' + str(counter).zfill(6) + '.jpg', frame)
#      18     counter+=1
#      19
#
# KeyboardInterrupt:

# %%
import os

files = os.listdir('./output')
lsorted = sorted(files,key=lambda x: int(os.path.splitext(x)[0]))

print(lsorted)
# Out:
# ['000252.jpg', '000254.jpg', '000256.jpg', '000258.jpg', '000260.jpg', '000262.jpg', '000264.jpg', '000266.jpg', '000268.jpg', '000270.jpg', '000272.jpg', '000274.jpg', '000276.jpg', '000278.jpg', '000280.jpg', '000282.jpg', '000284.jpg', '000286.jpg', '000288.jpg', '000290.jpg', '000292.jpg', '000294.jpg', '000296.jpg', '000298.jpg', '000300.jpg', '000302.jpg', '000304.jpg', '000306.jpg', '000308.jpg', '000310.jpg', '000312.jpg', '000314.jpg', '000316.jpg', '000318.jpg', '000320.jpg', '000322.jpg', '000324.jpg', '000326.jpg', '000328.jpg', '000330.jpg', '000332.jpg', '000334.jpg', '000336.jpg', '000338.jpg', '000340.jpg', '000342.jpg', '000344.jpg', '000346.jpg', '000348.jpg', '000350.jpg', '000352.jpg', '000354.jpg', '000356.jpg', '000358.jpg', '000360.jpg', '000362.jpg', '000364.jpg', '000366.jpg', '000368.jpg', '000370.jpg', '000372.jpg', '000374.jpg', '000376.jpg', '000378.jpg', '000380.jpg', '000382.jpg', '000384.jpg', '000386.jpg', '000388.jpg', '000390.jpg', '000392.jpg', '00
# ...

# %%
def write_to_file(file_path, data):
    with open(file_path, "a") as f:
        f.write(data)

# %%
def write_mot_format(frame, id, bbox, conf):
    """
    <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>, <conf>, <x>, <y>, <z>
    """

# %%
for thing in range(0,2): 
    write_to_file('./thing.txt', '1\n')
